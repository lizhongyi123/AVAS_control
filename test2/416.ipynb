# %%
from dataprovision.datasetparameter import DatasetParameter

dataset_path = r"C:\Users\shliu\Desktop\va417\DataSet10_cpu.txt"
obj1 = DatasetParameter(dataset_path)
obj1.get_parameter()
obj1_x = obj1.x

dataset_path = r"C:\Users\shliu\Desktop\va417\DataSet10_gpu.txt"
obj2 = DatasetParameter(dataset_path)
obj2.get_parameter()
obj2_x = obj2.x

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.use("TKAgg")
# 创建一个从 -2π 到 2π 的数组

# 绘制正弦曲线
plt.plot(obj1_x, label='sin(x)', linewidth=8, color='blue')
plt.plot(obj2_x, label='sin(x)', linewidth=4, color='red')

plt.show()

# %%
plt.plot(obj2_x, label='sin(x)', linewidth=1, color='blue')

plt.show()

# %%
from utils.readfile import read_txt

dataset_path = r"C:\Users\shliu\Desktop\va417\DataSet10_gpu.txt"
res =read_txt(dataset_path, out= "list")
print(res[-1][33])
print(res[-1][34])
print(res[-1][39])
# Out:
# 12.627601884270309
# 0.164513473982489
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 7
#       5 print(res[-1][33])
#       6 print(res[-1][34])
# ----> 7 print(res[-1][39])
#
# IndexError: list index out of range
