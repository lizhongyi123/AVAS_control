# %%
v = 500000 - 72576 - 36900 - 1.16
print(v)
# Out:
# 390522.84

# %%
v2 = 10 * 56 * 0.03 * 4000
print(v2)
# Out:
# 67200.0

# %%
v2 = 500000 - 67200 - 50900 - 11600
print(v2)
# Out:
# 370300

# %%
v2 = 500000 - 67200 - 50900 - 11600
print(v2)
# Out:
# 370300

# %%
print(10*56*4000)
# Out:
# 2240000

# %%
print(180*24)
# Out:
# 4320
